# %%
#!pip install tensorflow==2.8.0
#!pip install keras==2.8.0
#!pip install tensorflow-addons==0.17.0 #(0.20.0)

# %%
# Import libs
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.10.0 and strictly below 2.13.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
num_classes = 10
input_shape = (32,32,3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %%
x_train = x_train[:500]
y_train = y_train[:500]
x_test = x_test[:500]
y_test = y_test[:500]

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 40
image_size = 72 # We'll resize input images to this size
patch_size = 6 # Size of the patches to be extract from the imput images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim*2,
    projection_dim
] # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024] # Size of the dense layers of the final classifier

# %%
data_augmentation = keras.Sequential(
  [
    layers.Normalization(),
    layers.Resizing(image_size, image_size),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(factor=0.02),
    layers.RandomZoom(
        height_factor = 0.2, width_factor = 0.2)
  ],
  name="data_augmentation"
)
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation = tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size
        
    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1,self.patch_size, self.patch_size, 1],
            rates=[1,1,1,1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches,[batch_size,-1,patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4,4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i+1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder,self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim = num_patches, output_dim = projection_dim
        )
        
    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)
    
    # Create multiple layers of the Transformer block
    for _ in range(transformer_layers):
        # layer normalization 1
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attension layer
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1,x1)
        # skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection2.
        encoded_patches = layers.Add()([x3,x2])
    
    # Create a [batch_size, projection_dim] tensor
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras Model
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )
    
    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top_5_accuracy"),
        ],
    )
    
    checkpoint_filepath = "./tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuarcy",
        save_best_only=True,
        save_weights_only=True,
    )
    
    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )
    
    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100,2)}%")
    print(f"Test Top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

# %%
vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/40
# 2/2 [==============================] - ETA: 0s - loss: 6.0585 - accuracy: 0.0978 - top_5_accuracy: 0.5467 WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 35s 10s/step - loss: 6.0585 - accuracy: 0.0978 - top_5_accuracy: 0.5467 - val_loss: 5.7657 - val_accuracy: 0.1800 - val_top_5_accuracy: 0.7000
# Epoch 2/40
# 2/2 [==============================] - ETA: 0s - loss: 7.5224 - accuracy: 0.1933 - top_5_accuracy: 0.6089WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 7.5224 - accuracy: 0.1933 - top_5_accuracy: 0.6089 - val_loss: 3.8407 - val_accuracy: 0.2000 - val_top_5_accuracy: 0.5400
# Epoch 3/40
# 2/2 [==============================] - ETA: 0s - loss: 4.8558 - accuracy: 0.1711 - top_5_accuracy: 0.6289WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 4.8558 - accuracy: 0.1711 - top_5_accuracy: 0.6289 - val_loss: 2.6747 - val_accuracy: 0.2200 - val_top_5_accuracy: 0.8200
# Epoch 4/40
# 2/2 [==============================] - ETA: 0s - loss: 3.2243 - accuracy: 0.2444 - top_5_accuracy: 0.7089WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 3.2243 - accuracy: 0.2444 - top_5_accuracy: 0.7089 - val_loss: 2.2127 - val_accuracy: 0.3400 - val_top_5_accuracy: 0.7200
# Epoch 5/40
# 2/2 [==============================] - ETA: 0s - loss: 2.6582 - accuracy: 0.2156 - top_5_accuracy: 0.7244WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 2.6582 - accuracy: 0.2156 - top_5_accuracy: 0.7244 - val_loss: 2.0933 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.7200
# Epoch 6/40
# 2/2 [==============================] - ETA: 0s - loss: 2.3220 - accuracy: 0.2556 - top_5_accuracy: 0.7200WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 2.3220 - accuracy: 0.2556 - top_5_accuracy: 0.7200 - val_loss: 2.0488 - val_accuracy: 0.1800 - val_top_5_accuracy: 0.8400
# Epoch 7/40
# 2/2 [==============================] - ETA: 0s - loss: 2.2953 - accuracy: 0.2467 - top_5_accuracy: 0.7467WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 2.2953 - accuracy: 0.2467 - top_5_accuracy: 0.7467 - val_loss: 1.9099 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8200
# Epoch 8/40
# 2/2 [==============================] - ETA: 0s - loss: 2.1636 - accuracy: 0.2711 - top_5_accuracy: 0.7733WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 2.1636 - accuracy: 0.2711 - top_5_accuracy: 0.7733 - val_loss: 1.9273 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8000
# Epoch 9/40
# 2/2 [==============================] - ETA: 0s - loss: 2.0907 - accuracy: 0.3156 - top_5_accuracy: 0.7933WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 2.0907 - accuracy: 0.3156 - top_5_accuracy: 0.7933 - val_loss: 1.9801 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.7400
# Epoch 10/40
# 2/2 [==============================] - ETA: 0s - loss: 2.0010 - accuracy: 0.3156 - top_5_accuracy: 0.8067WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 2.0010 - accuracy: 0.3156 - top_5_accuracy: 0.8067 - val_loss: 1.9408 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.7200
# Epoch 11/40
# 2/2 [==============================] - ETA: 0s - loss: 1.9469 - accuracy: 0.3578 - top_5_accuracy: 0.8467WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.9469 - accuracy: 0.3578 - top_5_accuracy: 0.8467 - val_loss: 1.9038 - val_accuracy: 0.3400 - val_top_5_accuracy: 0.8000
# Epoch 12/40
# 2/2 [==============================] - ETA: 0s - loss: 1.9219 - accuracy: 0.3511 - top_5_accuracy: 0.8556WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.9219 - accuracy: 0.3511 - top_5_accuracy: 0.8556 - val_loss: 1.9163 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8000
# Epoch 13/40
# 2/2 [==============================] - ETA: 0s - loss: 1.8143 - accuracy: 0.3578 - top_5_accuracy: 0.8733WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.8143 - accuracy: 0.3578 - top_5_accuracy: 0.8733 - val_loss: 1.9534 - val_accuracy: 0.2400 - val_top_5_accuracy: 0.8200
# Epoch 14/40
# 2/2 [==============================] - ETA: 0s - loss: 1.8344 - accuracy: 0.3489 - top_5_accuracy: 0.8711WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.8344 - accuracy: 0.3489 - top_5_accuracy: 0.8711 - val_loss: 1.9983 - val_accuracy: 0.1000 - val_top_5_accuracy: 0.8200
# Epoch 15/40
# 2/2 [==============================] - ETA: 0s - loss: 1.7961 - accuracy: 0.3800 - top_5_accuracy: 0.8644WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.7961 - accuracy: 0.3800 - top_5_accuracy: 0.8644 - val_loss: 1.9884 - val_accuracy: 0.1400 - val_top_5_accuracy: 0.7800
# Epoch 16/40
# 2/2 [==============================] - ETA: 0s - loss: 1.7370 - accuracy: 0.4022 - top_5_accuracy: 0.8756WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.7370 - accuracy: 0.4022 - top_5_accuracy: 0.8756 - val_loss: 1.9456 - val_accuracy: 0.2000 - val_top_5_accuracy: 0.7800
# Epoch 17/40
# 2/2 [==============================] - ETA: 0s - loss: 1.6816 - accuracy: 0.4000 - top_5_accuracy: 0.9044WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.6816 - accuracy: 0.4000 - top_5_accuracy: 0.9044 - val_loss: 1.9473 - val_accuracy: 0.2000 - val_top_5_accuracy: 0.7800
# Epoch 18/40
# 2/2 [==============================] - ETA: 0s - loss: 1.6084 - accuracy: 0.4600 - top_5_accuracy: 0.9022WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.6084 - accuracy: 0.4600 - top_5_accuracy: 0.9022 - val_loss: 2.0152 - val_accuracy: 0.2000 - val_top_5_accuracy: 0.7800
# Epoch 19/40
# 2/2 [==============================] - ETA: 0s - loss: 1.6296 - accuracy: 0.4222 - top_5_accuracy: 0.9067WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.6296 - accuracy: 0.4222 - top_5_accuracy: 0.9067 - val_loss: 2.0349 - val_accuracy: 0.2200 - val_top_5_accuracy: 0.8200
# Epoch 20/40
# 2/2 [==============================] - ETA: 0s - loss: 1.6046 - accuracy: 0.4511 - top_5_accuracy: 0.8956WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.6046 - accuracy: 0.4511 - top_5_accuracy: 0.8956 - val_loss: 2.0115 - val_accuracy: 0.1800 - val_top_5_accuracy: 0.8000
# Epoch 21/40
# 2/2 [==============================] - ETA: 0s - loss: 1.4296 - accuracy: 0.4978 - top_5_accuracy: 0.9156WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.4296 - accuracy: 0.4978 - top_5_accuracy: 0.9156 - val_loss: 1.9659 - val_accuracy: 0.2200 - val_top_5_accuracy: 0.8400
# Epoch 22/40
# 2/2 [==============================] - ETA: 0s - loss: 1.4534 - accuracy: 0.4978 - top_5_accuracy: 0.9178WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.4534 - accuracy: 0.4978 - top_5_accuracy: 0.9178 - val_loss: 1.9311 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8400
# Epoch 23/40
# 2/2 [==============================] - ETA: 0s - loss: 1.4063 - accuracy: 0.5156 - top_5_accuracy: 0.9178WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.4063 - accuracy: 0.5156 - top_5_accuracy: 0.9178 - val_loss: 1.8907 - val_accuracy: 0.3400 - val_top_5_accuracy: 0.8200
# Epoch 24/40
# 2/2 [==============================] - ETA: 0s - loss: 1.3497 - accuracy: 0.5200 - top_5_accuracy: 0.9400WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.3497 - accuracy: 0.5200 - top_5_accuracy: 0.9400 - val_loss: 1.8254 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8600
# Epoch 25/40
# 2/2 [==============================] - ETA: 0s - loss: 1.3682 - accuracy: 0.5222 - top_5_accuracy: 0.9267WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.3682 - accuracy: 0.5222 - top_5_accuracy: 0.9267 - val_loss: 1.8749 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8800
# Epoch 26/40
# 2/2 [==============================] - ETA: 0s - loss: 1.3163 - accuracy: 0.5200 - top_5_accuracy: 0.9400WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.3163 - accuracy: 0.5200 - top_5_accuracy: 0.9400 - val_loss: 1.9414 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8400
# Epoch 27/40
# 2/2 [==============================] - ETA: 0s - loss: 1.2259 - accuracy: 0.5711 - top_5_accuracy: 0.9267WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.2259 - accuracy: 0.5711 - top_5_accuracy: 0.9267 - val_loss: 2.0220 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8000
# Epoch 28/40
# 2/2 [==============================] - ETA: 0s - loss: 1.3082 - accuracy: 0.5289 - top_5_accuracy: 0.9400WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.3082 - accuracy: 0.5289 - top_5_accuracy: 0.9400 - val_loss: 1.9692 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8200
# Epoch 29/40
# 2/2 [==============================] - ETA: 0s - loss: 1.1836 - accuracy: 0.5822 - top_5_accuracy: 0.9511WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.1836 - accuracy: 0.5822 - top_5_accuracy: 0.9511 - val_loss: 1.9942 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8200
# Epoch 30/40
# 2/2 [==============================] - ETA: 0s - loss: 1.0528 - accuracy: 0.6422 - top_5_accuracy: 0.9689WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.0528 - accuracy: 0.6422 - top_5_accuracy: 0.9689 - val_loss: 2.0939 - val_accuracy: 0.2400 - val_top_5_accuracy: 0.8400
# Epoch 31/40
# 2/2 [==============================] - ETA: 0s - loss: 1.0577 - accuracy: 0.6311 - top_5_accuracy: 0.9622WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.0577 - accuracy: 0.6311 - top_5_accuracy: 0.9622 - val_loss: 2.1550 - val_accuracy: 0.2400 - val_top_5_accuracy: 0.8000
# Epoch 32/40
# 2/2 [==============================] - ETA: 0s - loss: 1.0858 - accuracy: 0.6111 - top_5_accuracy: 0.9711WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.0858 - accuracy: 0.6111 - top_5_accuracy: 0.9711 - val_loss: 2.2017 - val_accuracy: 0.2400 - val_top_5_accuracy: 0.8000
# Epoch 33/40
# 2/2 [==============================] - ETA: 0s - loss: 1.0330 - accuracy: 0.6333 - top_5_accuracy: 0.9733WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 1.0330 - accuracy: 0.6333 - top_5_accuracy: 0.9733 - val_loss: 2.2246 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8000
# Epoch 34/40
# 2/2 [==============================] - ETA: 0s - loss: 0.9725 - accuracy: 0.6844 - top_5_accuracy: 0.9689WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 0.9725 - accuracy: 0.6844 - top_5_accuracy: 0.9689 - val_loss: 2.1199 - val_accuracy: 0.2800 - val_top_5_accuracy: 0.8000
# Epoch 35/40
# 2/2 [==============================] - ETA: 0s - loss: 0.8960 - accuracy: 0.6689 - top_5_accuracy: 0.9689WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 0.8960 - accuracy: 0.6689 - top_5_accuracy: 0.9689 - val_loss: 2.1974 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8000
# Epoch 36/40
# 2/2 [==============================] - ETA: 0s - loss: 0.9919 - accuracy: 0.6467 - top_5_accuracy: 0.9822WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 0.9919 - accuracy: 0.6467 - top_5_accuracy: 0.9822 - val_loss: 2.3486 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8400
# Epoch 37/40
# 2/2 [==============================] - ETA: 0s - loss: 0.8952 - accuracy: 0.6867 - top_5_accuracy: 0.9800WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 0.8952 - accuracy: 0.6867 - top_5_accuracy: 0.9800 - val_loss: 2.3225 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8400
# Epoch 38/40
# 2/2 [==============================] - ETA: 0s - loss: 0.9106 - accuracy: 0.6578 - top_5_accuracy: 0.9711WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 0.9106 - accuracy: 0.6578 - top_5_accuracy: 0.9711 - val_loss: 2.3866 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8200
# Epoch 39/40
# 2/2 [==============================] - ETA: 0s - loss: 0.7820 - accuracy: 0.7067 - top_5_accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 0.7820 - accuracy: 0.7067 - top_5_accuracy: 0.9867 - val_loss: 2.3671 - val_accuracy: 0.2600 - val_top_5_accuracy: 0.8000
# Epoch 40/40
# 2/2 [==============================] - ETA: 0s - loss: 0.7697 - accuracy: 0.7489 - top_5_accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuarcy available, skipping.
# 2/2 [==============================] - 17s 8s/step - loss: 0.7697 - accuracy: 0.7489 - top_5_accuracy: 0.9867 - val_loss: 2.3139 - val_accuracy: 0.3000 - val_top_5_accuracy: 0.8000
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22292/3547728248.py in <module>
#       1 vit_classifier = create_vit_classifier()
# ----> 2 history = run_experiment(vit_classifier)
#
# ~\AppData\Local\Temp/ipykernel_22292/4223509070.py in run_experiment(model)
#      30     )
#      31
# ---> 32     model.load_weights(checkpoint_filepath)
#      33     _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
#      34     print(f"Test accuracy: {round(accuracy * 100,2)}%")
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in error_translator(e)
#      29       'Failed to find any '
#      30       'matching files for') in error_message:
# ---> 31     raise errors_impl.NotFoundError(None, None, error_message)
#      32   elif 'Sliced checkpoints are not supported' in error_message or (
#      33       'Data type '
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ./tmp/checkpoint
